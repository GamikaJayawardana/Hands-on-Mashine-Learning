# %% [markdown]
# ![{C02B0DAA-1AF8-4F59-9B23-8DE7C2A2791F}.png](attachment:20457739-5099-4f2e-ac3f-4da13b5ed0ec.png)

# %% [markdown]
# ![{D571FB12-BA7D-4BAA-A0CB-77CE3D391525}.png](attachment:24fb94f4-7747-4d28-9273-4c496073f4f4.png)

# %%
import numpy as np

# %%
data = np.array([
    [26, 50000],
    [29, 70000],
    [34, 55000],
    [31, 41000]
])

# %% [markdown]
# Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)
scaled_data
# Out:
# array([[0.        , 0.31034483],
#        [0.375     , 1.        ],
#        [1.        , 0.48275862],
#        [0.625     , 0.        ]])

# %% [markdown]
# Standardization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
scaled_data
# Out:
# array([[-1.37198868, -0.3805212 ],
#        [-0.34299717,  1.52208478],
#        [ 1.37198868,  0.0951303 ],
#        [ 0.34299717, -1.23669388]])
