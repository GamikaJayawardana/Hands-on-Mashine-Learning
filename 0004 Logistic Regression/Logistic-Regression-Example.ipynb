# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("sample.csv")

# %%
data.head()
# Out:
#    age  job
# 0   16    0
# 1   24    0
# 2   31    1
# 3   29    0
# 4   40    1

# %%
data.tail()
# Out:
#     age  job
# 21   13    0
# 22   51    1
# 23   43    1
# 24   23    0
# 25   31    1

# %%
plt.scatter(data.age,data.job)
