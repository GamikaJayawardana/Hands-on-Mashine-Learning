# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'hours':[8, 1, 9, 5, 7.5, 9.5, 10, 7, 9, 9.5, 8, 10.5, 9, 6.5, 9],
    'score':[56, 70, 51, 24, 30, 66, 48, 36, 42, 61, 39, 87, 73,48,46]
})
